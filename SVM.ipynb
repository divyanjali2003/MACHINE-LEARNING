# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %%
iris=datasets.load_iris()
x,y=iris.data,iris.target

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
svm_model=SVC(kernel='linear')

# %%
svm_model.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = svm_model.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_pred)
print(f"SVM model Accuracy:{accuracy*100:.2f}%")
# Out:
# SVM model Accuracy:100.00%

# %%
import pandas as pd
df=pd.read_csv('Crime_Data_from_2020_to_Present.csv')
df.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130     7
# 1  200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800     1
# 2  200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700     3
# 3  200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037     9
# 4  200412582  09/09/2020 12:00:00 AM  09/09/2020 12:00:00 AM       630     4
#
#     AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0    Wilshire          784         1     510
# 1     Central          182         1     330
# 2   Southwest          356         1     480
# 3    Van Nuys          964         1     343
# 4  Hollenbeck          413         1     510
#
#                                 Crm Cd Desc  ... Status   Status Desc  \
# 0                          VEHICLE - STOLEN  ...     AA  Adult Arrest
# 1                     BURGLARY FROM VEHICLE  ...     IC   Invest Cont
# 2                             BIKE - STOLEN  ...     IC   Invest Cont
# 3  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)  ...     IC   Invest Cont
# 4                          VEHICLE - STOLEN  ...     IC   Invest Cont
#
#   Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0    510.0    998.0       NaN      NaN
# 1    330.0    998.0       NaN      NaN
# 2    480.0      NaN       NaN      NaN
# 3    343.0      NaN       NaN      NaN
# 4    510.0      NaN       NaN      NaN
#
#                                    LOCATION Cross Street      LAT       LON
# 0   1900 S  LONGWOOD                     AV          NaN  34.0375 -118.3506
# 1   1000 S  FLOWER                       ST          NaN  34.0444 -118.2628
# 2   1400 W  37TH                         ST          NaN  34.0210 -118.3002
# 3  14000    RIVERSIDE                    DR          NaN  34.1576 -118.4387
# 4                          200 E  AVENUE 28          NaN  34.0820 -118.2130
#
# [5 rows x 28 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['AREA NAME']=le.fit_transform(df['AREA NAME'])
df.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130     7
# 1  200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800     1
# 2  200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700     3
# 3  200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037     9
# 4  200412582  09/09/2020 12:00:00 AM  09/09/2020 12:00:00 AM       630     4
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0         20          784         1     510
# 1          1          182         1     330
# 2         15          356         1     480
# 3         17          964         1     343
# 4          5          413         1     510
#
#                                 Crm Cd Desc  ... Status   Status Desc  \
# 0                          VEHICLE - STOLEN  ...     AA  Adult Arrest
# 1                     BURGLARY FROM VEHICLE  ...     IC   Invest Cont
# 2                             BIKE - STOLEN  ...     IC   Invest Cont
# 3  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)  ...     IC   Invest Cont
# 4                          VEHICLE - STOLEN  ...     IC   Invest Cont
#
#   Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0    510.0    998.0       NaN      NaN
# 1    330.0    998.0       NaN      NaN
# 2    480.0      NaN       NaN      NaN
# 3    343.0      NaN       NaN      NaN
# 4    510.0      NaN       NaN      NaN
#
#                                    LOCATION Cross Street      LAT   LON
# 0   1900 S  LONGWOOD                     AV          NaN  34.0375  3076
# 1   1000 S  FLOWER                       ST          NaN  34.0444  3954
# 2   1400 W  37TH                         ST          NaN  34.0210  3580
# 3  14000    RIVERSIDE                    DR          NaN  34.1576  2195
# 4                          200 E  AVENUE 28          NaN  34.0820  4452
#
# [5 rows x 28 columns]

# %%
x=df.drop(['AREA NAME'],axis=1)
x.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130     7
# 1  200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800     1
# 2  200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700     3
# 3  200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037     9
# 4  200412582  09/09/2020 12:00:00 AM  09/09/2020 12:00:00 AM       630     4
#
#    Rpt Dist No  Part 1-2  Crm Cd                               Crm Cd Desc  \
# 0          784         1     510                          VEHICLE - STOLEN
# 1          182         1     330                     BURGLARY FROM VEHICLE
# 2          356         1     480                             BIKE - STOLEN
# 3          964         1     343  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)
# 4          413         1     510                          VEHICLE - STOLEN
#
#           Mocodes  ...  Status   Status Desc Crm Cd 1  Crm Cd 2 Crm Cd 3  \
# 0             NaN  ...      AA  Adult Arrest    510.0     998.0      NaN
# 1  1822 1402 0344  ...      IC   Invest Cont    330.0     998.0      NaN
# 2       0344 1251  ...      IC   Invest Cont    480.0       NaN      NaN
# 3       0325 1501  ...      IC   Invest Cont    343.0       NaN      NaN
# 4             NaN  ...      IC   Invest Cont    510.0       NaN      NaN
#
#    Crm Cd 4                                  LOCATION Cross Street      LAT  \
# 0       NaN   1900 S  LONGWOOD                     AV          NaN  34.0375
# 1       NaN   1000 S  FLOWER                       ST          NaN  34.0444
# 2       NaN   1400 W  37TH                         ST          NaN  34.0210
# 3       NaN  14000    RIVERSIDE                    DR          NaN  34.1576
# 4       NaN                          200 E  AVENUE 28          NaN  34.0820
#
#     LON
# 0  3076
# 1  3954
# 2  3580
# 3  2195
# 4  4452
#
# [5 rows x 27 columns]

# %%
y=df['AREA NAME']
y.head()
# Out:
# 0    20
# 1     1
# 2    15
# 3    17
# 4     5
# Name: AREA NAME, dtype: int32

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=100)
x_train
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 845385  231717451  11/09/2023 12:00:00 AM  11/09/2023 12:00:00 AM      2350
# 771925  230317407  09/30/2023 12:00:00 AM  09/29/2023 12:00:00 AM      1700
# 106943  201106306  02/20/2020 12:00:00 AM  02/19/2020 12:00:00 AM      2000
# 554340  220406549  03/17/2022 12:00:00 AM  03/16/2022 12:00:00 AM       900
# 485179  221013277  08/27/2022 12:00:00 AM  08/26/2022 12:00:00 AM      2350
# ...           ...                     ...                     ...       ...
# 864087  230119506  09/08/2023 12:00:00 AM  09/08/2023 12:00:00 AM      1432
# 778087  230614350  08/26/2023 12:00:00 AM  08/25/2023 12:00:00 AM      1247
# 210755  211908167  04/30/2021 12:00:00 AM  04/29/2021 12:00:00 AM      2000
# 56088   201215750  07/02/2020 12:00:00 AM  07/02/2020 12:00:00 AM       850
# 824840  230813134  08/12/2023 12:00:00 AM  08/12/2023 12:00:00 AM       340
#
#         AREA  Rpt Dist No  Part 1-2  Crm Cd  \
# 845385    17         1718         1     310
# 771925     3          357         1     522
# 106943    11         1119         1     310
# 554340     4          491         1     420
# 485179    10         1035         1     510
# ...      ...          ...       ...     ...
# 864087     1          119         2     956
# 778087     6          642         1     320
# 210755    19         1909         1     331
# 56088     12         1259         1     230
# 824840     8          881         1     331
#
#                                               Crm Cd Desc  \
# 845385                                           BURGLARY
# 771925  VEHICLE, STOLEN - OTHER (MOTORIZED SCOOTERS, B...
# 106943                                           BURGLARY
# 554340    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# 485179                                   VEHICLE - STOLEN
# ...                                                   ...
# 864087            LETTERS, LEWD  -  TELEPHONE CALLS, LEWD
# 778087                                BURGLARY, ATTEMPTED
# 210755  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...
# 56088      ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 824840  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...
#
#                          Mocodes  ...  Status  Status Desc Crm Cd 1  Crm Cd 2  \
# 845385  1202 0344 0216 1606 0321  ...      IC  Invest Cont    310.0       NaN
# 771925                       NaN  ...      IC  Invest Cont    522.0       NaN
# 106943                      0344  ...      IC  Invest Cont    310.0       NaN
# 554340                       NaN  ...      IC  Invest Cont    420.0       NaN
# 485179                       NaN  ...      IC  Invest Cont    510.0       NaN
# ...                          ...  ...     ...          ...      ...       ...
# 864087       0400 1822 1501 0910  ...      IC  Invest Cont    956.0       NaN
# 778087       0329 1205 1822 1501  ...      IC  Invest Cont    320.0       NaN
# 210755                      0385  ...      IC  Invest Cont    331.0       NaN
# 56088   0342 1822 0334 0353 0302  ...      IC  Invest Cont    230.0       NaN
# 824840                 0344 0346  ...      IC  Invest Cont    331.0       NaN
#
#        Crm Cd 3  Crm Cd 4                                  LOCATION  \
# 845385      NaN       NaN  11100    COLLETT                      AV
# 771925      NaN       NaN   1100 W  37TH                         ST
# 106943      NaN       NaN   1200    NEOLA                        ST
# 554340      NaN       NaN   2500 E  OLYMPIC                      BL
# 485179      NaN       NaN   6700    RESEDA                       BL
# ...         ...       ...                                       ...
# 864087      NaN       NaN                         00    GATEWAY PLZ
# 778087      NaN       NaN   7700 W  SUNSET                       BL
# 210755      NaN       NaN  13800    GAVINA                       AV
# 56088       NaN       NaN                                    AVALON
# 824840      NaN       NaN   2200    WELLESLEY                    AV
#
#                            Cross Street      LAT   LON
# 845385                              NaN  34.2728  1746
# 771925                              NaN  34.0210  3661
# 106943                              NaN  34.1347  4663
# 554340                              NaN  34.0254  4343
# 485179                              NaN  34.1925  1223
# ...                                 ...      ...   ...
# 864087                              NaN  34.0547  4247
# 778087                              NaN  34.0981  3010
# 210755                              NaN  34.3229  2498
# 56088   78TH                         ST  33.9684  3930
# 824840                              NaN  34.0311  2035
#
# [703392 rows x 27 columns]

# %%
x_train
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 845385  231717451  11/09/2023 12:00:00 AM  11/09/2023 12:00:00 AM      2350
# 771925  230317407  09/30/2023 12:00:00 AM  09/29/2023 12:00:00 AM      1700
# 106943  201106306  02/20/2020 12:00:00 AM  02/19/2020 12:00:00 AM      2000
# 554340  220406549  03/17/2022 12:00:00 AM  03/16/2022 12:00:00 AM       900
# 485179  221013277  08/27/2022 12:00:00 AM  08/26/2022 12:00:00 AM      2350
# ...           ...                     ...                     ...       ...
# 864087  230119506  09/08/2023 12:00:00 AM  09/08/2023 12:00:00 AM      1432
# 778087  230614350  08/26/2023 12:00:00 AM  08/25/2023 12:00:00 AM      1247
# 210755  211908167  04/30/2021 12:00:00 AM  04/29/2021 12:00:00 AM      2000
# 56088   201215750  07/02/2020 12:00:00 AM  07/02/2020 12:00:00 AM       850
# 824840  230813134  08/12/2023 12:00:00 AM  08/12/2023 12:00:00 AM       340
#
#         AREA  Rpt Dist No  Part 1-2  Crm Cd  \
# 845385    17         1718         1     310
# 771925     3          357         1     522
# 106943    11         1119         1     310
# 554340     4          491         1     420
# 485179    10         1035         1     510
# ...      ...          ...       ...     ...
# 864087     1          119         2     956
# 778087     6          642         1     320
# 210755    19         1909         1     331
# 56088     12         1259         1     230
# 824840     8          881         1     331
#
#                                               Crm Cd Desc  \
# 845385                                           BURGLARY
# 771925  VEHICLE, STOLEN - OTHER (MOTORIZED SCOOTERS, B...
# 106943                                           BURGLARY
# 554340    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# 485179                                   VEHICLE - STOLEN
# ...                                                   ...
# 864087            LETTERS, LEWD  -  TELEPHONE CALLS, LEWD
# 778087                                BURGLARY, ATTEMPTED
# 210755  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...
# 56088      ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 824840  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...
#
#                          Mocodes  ...  Status  Status Desc Crm Cd 1  Crm Cd 2  \
# 845385  1202 0344 0216 1606 0321  ...      IC  Invest Cont    310.0       NaN
# 771925                       NaN  ...      IC  Invest Cont    522.0       NaN
# 106943                      0344  ...      IC  Invest Cont    310.0       NaN
# 554340                       NaN  ...      IC  Invest Cont    420.0       NaN
# 485179                       NaN  ...      IC  Invest Cont    510.0       NaN
# ...                          ...  ...     ...          ...      ...       ...
# 864087       0400 1822 1501 0910  ...      IC  Invest Cont    956.0       NaN
# 778087       0329 1205 1822 1501  ...      IC  Invest Cont    320.0       NaN
# 210755                      0385  ...      IC  Invest Cont    331.0       NaN
# 56088   0342 1822 0334 0353 0302  ...      IC  Invest Cont    230.0       NaN
# 824840                 0344 0346  ...      IC  Invest Cont    331.0       NaN
#
#        Crm Cd 3  Crm Cd 4                                  LOCATION  \
# 845385      NaN       NaN  11100    COLLETT                      AV
# 771925      NaN       NaN   1100 W  37TH                         ST
# 106943      NaN       NaN   1200    NEOLA                        ST
# 554340      NaN       NaN   2500 E  OLYMPIC                      BL
# 485179      NaN       NaN   6700    RESEDA                       BL
# ...         ...       ...                                       ...
# 864087      NaN       NaN                         00    GATEWAY PLZ
# 778087      NaN       NaN   7700 W  SUNSET                       BL
# 210755      NaN       NaN  13800    GAVINA                       AV
# 56088       NaN       NaN                                    AVALON
# 824840      NaN       NaN   2200    WELLESLEY                    AV
#
#                            Cross Street      LAT   LON
# 845385                              NaN  34.2728  1746
# 771925                              NaN  34.0210  3661
# 106943                              NaN  34.1347  4663
# 554340                              NaN  34.0254  4343
# 485179                              NaN  34.1925  1223
# ...                                 ...      ...   ...
# 864087                              NaN  34.0547  4247
# 778087                              NaN  34.0981  3010
# 210755                              NaN  34.3229  2498
# 56088   78TH                         ST  33.9684  3930
# 824840                              NaN  34.0311  2035
#
# [703392 rows x 27 columns]

# %%
x_test
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 414328  220618438  10/30/2022 12:00:00 AM  10/30/2022 12:00:00 AM      1115
# 532025  220811444  07/01/2022 12:00:00 AM  06/30/2022 12:00:00 AM      1000
# 65218   200919015  12/31/2020 12:00:00 AM  12/28/2020 12:00:00 AM      1600
# 540989  221317406  09/09/2022 12:00:00 AM  09/09/2022 12:00:00 AM      1540
# 288467  211504356  01/11/2021 12:00:00 AM  01/11/2021 12:00:00 AM      1500
# ...           ...                     ...                     ...       ...
# 65649   200911083  06/16/2020 12:00:00 AM  06/12/2020 12:00:00 AM      1700
# 81698   200218611  12/14/2020 12:00:00 AM  07/15/2020 12:00:00 AM       900
# 307699  212108771  05/12/2021 12:00:00 AM  05/11/2021 12:00:00 AM      2330
# 864951  230124602  11/22/2023 12:00:00 AM  11/21/2023 12:00:00 AM       900
# 330692  210817771  12/20/2021 12:00:00 AM  12/19/2021 12:00:00 AM       500
#
#         AREA  Rpt Dist No  Part 1-2  Crm Cd  \
# 414328     6          648         1     341
# 532025     8          855         1     330
# 65218      9          923         1     341
# 540989    13         1313         1     230
# 288467    15         1555         1     440
# ...      ...          ...       ...     ...
# 65649      9          991         1     331
# 81698      2          203         1     510
# 307699    21         2189         1     510
# 864951     1          182         1     510
# 330692     8          895         1     420
#
#                                               Crm Cd Desc  \
# 414328  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...
# 532025                              BURGLARY FROM VEHICLE
# 65218   THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...
# 540989     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 288467                 THEFT PLAIN - PETTY ($950 & UNDER)
# ...                                                   ...
# 65649   THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...
# 81698                                    VEHICLE - STOLEN
# 307699                                   VEHICLE - STOLEN
# 864951                                   VEHICLE - STOLEN
# 330692    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
#
#                     Mocodes  ...  Status   Status Desc Crm Cd 1  Crm Cd 2  \
# 414328  0344 1822 1501 0910  ...      IC   Invest Cont    341.0       NaN
# 532025  0344 1300 1609 1822  ...      IC   Invest Cont    330.0       NaN
# 65218        0397 0344 1822  ...      IC   Invest Cont    341.0       NaN
# 540989  1218 0411 1822 2033  ...      IC   Invest Cont    230.0       NaN
# 288467                 0344  ...      IC   Invest Cont    440.0       NaN
# ...                     ...  ...     ...           ...      ...       ...
# 65649        0344 1822 0321  ...      IC   Invest Cont    331.0       NaN
# 81698                   NaN  ...      IC   Invest Cont    510.0       NaN
# 307699                  NaN  ...      AA  Adult Arrest    510.0       NaN
# 864951                  NaN  ...      IC   Invest Cont    510.0       NaN
# 330692                  NaN  ...      IC   Invest Cont    420.0       NaN
#
#        Crm Cd 3  Crm Cd 4                                  LOCATION  \
# 414328      NaN       NaN   5400    HOLLYWOOD                    BL
# 532025      NaN       NaN   1400    VETERAN                      AV
# 65218       NaN       NaN  14500    GILMORE                      ST
# 540989      NaN       NaN           16TH                         ST
# 288467      NaN       NaN   5100    LANKERSHIM                   BL
# ...         ...       ...                                       ...
# 65649       NaN       NaN   3400    VISTA HAVEN                  RD
# 81698       NaN       NaN   4000    MELROSE                      AV
# 307699      NaN       NaN  20200    VENTURA                      BL
# 864951      NaN       NaN    700 W  OLYMPIC                      BL
# 330692      NaN       NaN   3400    CLUB                         DR
#
#                            Cross Street      LAT   LON
# 414328                              NaN  34.1017  3510
# 532025                              NaN  34.0517  2162
# 65218                               NaN  34.1876  2086
# 540989  GRIFFIN                      AV  34.0286  4037
# 288467                              NaN  34.1630  2847
# ...                                 ...      ...   ...
# 65649                               NaN  34.1333  1919
# 81698                               NaN  34.0851  3701
# 307699                              NaN  34.1702   853
# 864951                              NaN  34.0444  3954
# 330692                              NaN  34.0308  2555
#
# [301455 rows x 27 columns]

# %%
y_train
# Out:
# 845385     2
# 771925    15
# 106943    10
# 554340     5
# 485179    19
#           ..
# 864087     1
# 778087     6
# 210755     7
# 56088      0
# 824840    18
# Name: AREA NAME, Length: 703392, dtype: int32

# %%
x_test
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 414328  220618438  10/30/2022 12:00:00 AM  10/30/2022 12:00:00 AM      1115
# 532025  220811444  07/01/2022 12:00:00 AM  06/30/2022 12:00:00 AM      1000
# 65218   200919015  12/31/2020 12:00:00 AM  12/28/2020 12:00:00 AM      1600
# 540989  221317406  09/09/2022 12:00:00 AM  09/09/2022 12:00:00 AM      1540
# 288467  211504356  01/11/2021 12:00:00 AM  01/11/2021 12:00:00 AM      1500
# ...           ...                     ...                     ...       ...
# 65649   200911083  06/16/2020 12:00:00 AM  06/12/2020 12:00:00 AM      1700
# 81698   200218611  12/14/2020 12:00:00 AM  07/15/2020 12:00:00 AM       900
# 307699  212108771  05/12/2021 12:00:00 AM  05/11/2021 12:00:00 AM      2330
# 864951  230124602  11/22/2023 12:00:00 AM  11/21/2023 12:00:00 AM       900
# 330692  210817771  12/20/2021 12:00:00 AM  12/19/2021 12:00:00 AM       500
#
#         AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 414328     6    Hollywood          648         1     341
# 532025     8      West LA          855         1     330
# 65218      9     Van Nuys          923         1     341
# 540989    13       Newton         1313         1     230
# 288467    15  N Hollywood         1555         1     440
# ...      ...          ...          ...       ...     ...
# 65649      9     Van Nuys          991         1     331
# 81698      2      Rampart          203         1     510
# 307699    21      Topanga         2189         1     510
# 864951     1      Central          182         1     510
# 330692     8      West LA          895         1     420
#
#                                               Crm Cd Desc  ...  \
# 414328  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...  ...
# 532025                              BURGLARY FROM VEHICLE  ...
# 65218   THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...  ...
# 540989     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...
# 288467                 THEFT PLAIN - PETTY ($950 & UNDER)  ...
# ...                                                   ...  ...
# 65649   THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...  ...
# 81698                                    VEHICLE - STOLEN  ...
# 307699                                   VEHICLE - STOLEN  ...
# 864951                                   VEHICLE - STOLEN  ...
# 330692    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)  ...
#
#                         Weapon Desc  Status   Status Desc Crm Cd 1  Crm Cd 2  \
# 414328                          NaN      IC   Invest Cont    341.0       NaN
# 532025                          NaN      IC   Invest Cont    330.0       NaN
# 65218                           NaN      IC   Invest Cont    341.0       NaN
# 540989  UNKNOWN WEAPON/OTHER WEAPON      IC   Invest Cont    230.0       NaN
# 288467                          NaN      IC   Invest Cont    440.0       NaN
# ...                             ...     ...           ...      ...       ...
# 65649                           NaN      IC   Invest Cont    331.0       NaN
# 81698                           NaN      IC   Invest Cont    510.0       NaN
# 307699                          NaN      AA  Adult Arrest    510.0       NaN
# 864951                          NaN      IC   Invest Cont    510.0       NaN
# 330692                          NaN      IC   Invest Cont    420.0       NaN
#
#        Crm Cd 3  Crm Cd 4                                  LOCATION  \
# 414328      NaN       NaN   5400    HOLLYWOOD                    BL
# 532025      NaN       NaN   1400    VETERAN                      AV
# 65218       NaN       NaN  14500    GILMORE                      ST
# 540989      NaN       NaN           16TH                         ST
# 288467      NaN       NaN   5100    LANKERSHIM                   BL
# ...         ...       ...                                       ...
# 65649       NaN       NaN   3400    VISTA HAVEN                  RD
# 81698       NaN       NaN   4000    MELROSE                      AV
# 307699      NaN       NaN  20200    VENTURA                      BL
# 864951      NaN       NaN    700 W  OLYMPIC                      BL
# 330692      NaN       NaN   3400    CLUB                         DR
#
#                            Cross Street      LAT
# 414328                              NaN  34.1017
# 532025                              NaN  34.0517
# 65218                               NaN  34.1876
# 540989  GRIFFIN                      AV  34.0286
# 288467                              NaN  34.1630
# ...                                 ...      ...
# 65649                               NaN  34.1333
# 81698                               NaN  34.0851
# 307699                              NaN  34.1702
# 864951                              NaN  34.0444
# 330692                              NaN  34.0308
#
# [301455 rows x 27 columns]

# %%
from sklearn.preprocessing import StandardScaler
sl=StandardScaler()
x_train=sl.fit_transform(x_train)
x_test=sl.fit_transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_129980\4197423019.py in ?()
#       1 from sklearn.preprocessing import StandardScaler
#       2 sl=StandardScaler()
# ----> 3 x_train=sl.fit_transform(x_train)
#       4 x_test=sl.fit_transform(x_test)
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     311     @wraps(f)
#     312     def wrapped(self, X, *args, **kwargs):
# --> 313         data_to_wrap = f(self, X, *args, **kwargs)
#     314         if isinstance(data_to_wrap, tuple):
#     315             # only wrap the first output for cross decomposition
#     316             return_tuple = (
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
#    1094                 )
#    1095
#    1096         if y is None:
#    1097             # fit method of arity 1 (unsupervised transformation)
# -> 1098             return self.fit(X, **fit_params).transform(X)
#    1099         else:
#    1100             # fit method of arity 2 (supervised transformation)
#    1101             return self.fit(X, y, **fit_params).transform(X)
#
# ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, y, sample_weight)
#     874             Fitted scaler.
#     875         """
#     876         # Reset internal state before fitting
#     877         self._reset()
# --> 878         return self.partial_fit(X, y, sample_weight)
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, y, sample_weight)
#     910         self : object
#     911             Fitted scaler.
#     912         """
#     913         first_call = not hasattr(self, "n_samples_seen_")
# --> 914         X = self._validate_data(
#     915             X,
#     916             accept_sparse=("csr", "csc"),
#     917             dtype=FLOAT_DTYPES,
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     629                 out = y
#     630             else:
#     631                 out = X, y
#     632         elif not no_val_X and no_val_y:
# --> 633             out = check_array(X, input_name="X", **check_params)
#     634         elif no_val_X and not no_val_y:
#     635             out = _check_y(y, **check_params)
#     636         else:
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1009                         )
#    1010                     array = xp.astype(array, dtype, copy=False)
#    1011                 else:
#    1012                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1013             except ComplexWarning as complex_warning:
#    1014                 raise ValueError(
#    1015                     "Complex data not supported\n{}\n".format(array)
#    1016                 ) from complex_warning
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     747         # Use NumPy API to support order
#     748         if copy is True:
#     749             array = numpy.array(array, order=order, dtype=dtype)
#     750         else:
# --> 751             array = numpy.asarray(array, order=order, dtype=dtype)
#     752
#     753         # At this point array is a NumPy ndarray. We convert it to an array
#     754         # container that is consistent with the input's namespace.
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# ValueError: could not convert string to float: '11/09/2023 12:00:00 AM'
